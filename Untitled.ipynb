# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("data/data.txt")

# %%
data[["angle_1", "angle_2"]] = data[["angle_1", "angle_2"]].apply(pd.to_numeric)

# %%
data
# Out:
#      angle_1  angle_2  angle_3  angle_4  angle_5  angle_6  angle_7  angle_8  \
# 0        169      165      124      127       26       23      174      175
# 1        157      163       90       89       49       56      179      178
# 2        166      166      101      105       52       49      175      176
# 3        150      167      131      135       23       30      179      180
# 4        154      156      113      114       28       27      173      174
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 235      170      171       38       43      112      109      178      179
# 236      170      166       27       22       90       93      168      165
# 237      175      158       49       36       84       89      176      176
# 238      168      167       77       73       64       69      179      178
# 239      170      175       69       70       74       73      179      177
#
#      angle_9  angle_10  ground_truth
# 0        137       144             3
# 1        129       123             3
# 2        161       171             3
# 3        136       153             3
# 4        108       136             3
# ..       ...       ...           ...
# 235      179       179             0
# 236      176       170             0
# 237      167       172             0
# 238      172       168             0
# 239      179       174             0
#
# [240 rows x 11 columns]

# %%
X_data = data.drop(columns=['ground_truth'])

# %%
X_data
# Out:
#      angle_1  angle_2  angle_3  angle_4  angle_5  angle_6  angle_7  angle_8  \
# 0        169      165      124      127       26       23      174      175
# 1        157      163       90       89       49       56      179      178
# 2        166      166      101      105       52       49      175      176
# 3        150      167      131      135       23       30      179      180
# 4        154      156      113      114       28       27      173      174
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 235      170      171       38       43      112      109      178      179
# 236      170      166       27       22       90       93      168      165
# 237      175      158       49       36       84       89      176      176
# 238      168      167       77       73       64       69      179      178
# 239      170      175       69       70       74       73      179      177
#
#      angle_9  angle_10
# 0        137       144
# 1        129       123
# 2        161       171
# 3        136       153
# 4        108       136
# ..       ...       ...
# 235      179       179
# 236      176       170
# 237      167       172
# 238      172       168
# 239      179       174
#
# [240 rows x 10 columns]

# %%
y_data = data['ground_truth']

# %%
y_data
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 235    0
# 236    0
# 237    0
# 238    0
# 239    0
# Name: ground_truth, Length: 240, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      angle_1  angle_2  angle_3  angle_4  angle_5  angle_6  angle_7  angle_8  \
# 139      166      165      102      106       62       57      171      164
# 60       174      173      157      154       18       20      180      179
# 204      169      170       44       46       80       78      175      173
# 186      163      164       58       61       87       82      178      177
# 207      166      173       39       46       89       84      176      176
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 106      136      123      102      100       46       43      176      169
# 14       180      179      120      119       33       36      176      176
# 92       170      169      137      143       29       25      164      164
# 179      170      169      117      123       56       48      179      179
# 102      173      170      135      130       31       35      178      180
#
#      angle_9  angle_10
# 139      179       180
# 60       135       147
# 204      176       180
# 186      168       172
# 207      166       176
# ..       ...       ...
# 106      146       124
# 14       134       122
# 92       138       130
# 179      161       156
# 102       99       117
#
# [192 rows x 10 columns]

# %%
y_train
# Out:
# 139    1
# 60     2
# 204    0
# 186    0
# 207    0
#       ..
# 106    2
# 14     3
# 92     2
# 179    1
# 102    2
# Name: ground_truth, Length: 192, dtype: int64

# %%
import glob
data = [[f, 0] for f in glob.glob('data/forwardBend125/*.*')]
data = data + [[f, 1] for f in glob.glob('data/forwardBend250/*.*')]
data = data + [[f, 2] for f in glob.glob('data/forwardBend375/*.*')]
data = data + [[f, 3] for f in glob.glob('data/forwardBend500/*.*')]

# %%
data
# Out:
# [['data/forwardBend125\\10.jpg', 0],
#  ['data/forwardBend125\\13.jpg', 0],
#  ['data/forwardBend125\\17.jpg', 0],
#  ['data/forwardBend125\\2.jpg', 0],
#  ['data/forwardBend125\\21.jpg', 0],
#  ['data/forwardBend125\\23.jpg', 0],
#  ['data/forwardBend125\\24.jpg', 0],
#  ['data/forwardBend125\\25.jpg', 0],
#  ['data/forwardBend125\\27.jpg', 0],
#  ['data/forwardBend125\\28.jpg', 0],
#  ['data/forwardBend125\\29.jpg', 0],
#  ['data/forwardBend125\\3.jpg', 0],
#  ['data/forwardBend125\\31.jpg', 0],
#  ['data/forwardBend125\\34.jpg', 0],
#  ['data/forwardBend125\\35.jpg', 0],
#  ['data/forwardBend125\\36.jpg', 0],
#  ['data/forwardBend125\\38.jpg', 0],
#  ['data/forwardBend125\\41.jpg', 0],
#  ['data/forwardBend125\\42.jpg', 0],
#  ['data/forwardBend125\\44.jpg', 0],
#  ['data/forwardBend125\\45.jpg', 0],
#  ['data/forwardBend125\\46.jpg', 0],
#  ['data/forwardBend125\\48.jpg', 0],
#  ['data/forwardBend125\\49.jpg', 0],
#  ['data/forwardBend125\\50.jpg', 0],
#  ['data/forwardBend125\\52.jpg', 0],
#  ['data/forwardBend125\\56.jpg', 0],
#  ['data/forwardBend125\\60.jpg', 0],
#  ['data/forwardBend125\\7.jpg', 0],
#  ['data/forwardBend250\\1.jpg', 1],
#  ['data/forwardBend250\\15.jpg', 1],
#  ['data/forwardBend250\\2.jpg', 1],
#  ['data/forwardBend250\\20.jpg', 1],
#  ['data/forwardBend250\\24.jpg', 1],
#  ['data/forwardBend250\\29.jpg', 1],
#  ['data/forwardBend250\\43.jpg', 1],
#  ['data/forwardBend250\\44.jpg', 1],
#  ['data/forwardBend250\\46.jpg', 1],
#  ['data/forwardBend250\\49.jpg', 1],
#  ['data/forwardBend250\\image1.png', 1],
#  ['data/forwardBend250\\image10.png', 1],
#  ['data/forwardBend250\\image11.png', 1],
#  ['data/forwardBend250\\image12.png', 1],
#  ['data/forwardBend250\\image13.png', 1],
#  ['data/forwardBend250\\image14.png', 1],
#  ['data/forwardBend250\\image15.png', 1],
#  ['data/forwardBend250\\image17.png', 1],
#  ['data/forwardBend250\\image18.png', 1],
#  ['data/forwardBend250\\image2.png', 1],
#  ['data/forwardBend250\\image20.png', 1],
#  ['data/forwardBend250\\image21.png', 1],
#  ['data/forwardBend250\\image22.png', 1],
#  ['data/forwardBend250\\image27.png', 1],
#  ['data/forwardBend250\\image28.png', 1],
#  ['data/forwardBend250\\image33.png', 1],
#  ['data/forwardBend250\\image34.png', 1],
#  ['data/forwardBend250\\image35.png', 1],
#  ['data/forwardBend250\\image36.png', 1],
#  ['data/forwardBend250\\image4.png', 1],
#  ['data/forwardBend250\\image5.png', 1],
#  ['data/forwardBend250\\image6.png', 1],
#  ['data/forwardBend250\\image7.png', 1],
#  ['data/forwardBend250\\image8.png', 1],
#  ['data/forwardBend250\\image9.png', 1],
#  ['data/forwardBend375\\1.jpg', 2],
#  ['data/forwardBend375\\11.jpg', 2],
#  ['data/forwardBend375\\15.jpg', 2],
#  ['data/forwardBend375\\17.jpg', 2],
#  ['data/forwardBend375\\28.jpg', 2],
#  ['data/forwardBend375\\29.jpg', 2],
#  ['data/forwardBend375\\3.jpg', 2],
#  ['data/forwardBend375\\30.jpg', 2],
#  ['data/forwardBend375\\34.jpg', 2],
#  ['data/forwardBend375\\35.jpg', 2],
#  ['data/forwardBend375\\36.jpg', 2],
#  ['data/forwardBend375\\37.jpg', 2],
#  ['data/forwardBend375\\38.jpg', 2],
#  ['data/forwardBend375\\42.jpg', 2],
#  ['data/forwardBend375\\43.jpg', 2],
#  ['data/forwardBend375\\44.jpg', 2],
#  ['data/forwardBend375\\46.jpg', 2],
#  ['data/forwardBend375\\50.jpg', 2],
#  ['data/forwardBend375\\52.jpg', 2],
#  ['data/forwardBend375\\55.jpg', 2],
#  ['data/forwardBend375\\56.jpg', 2],
#  ['data/forwardBend375\\7.jpg', 2],
#  ['data/forwardBend375\\8.jpg', 2],
#  ['data/forwardBend375\\image1.png', 2],
#  ['data/forwardBend375\\image10.png', 2],
#  ['data/forwardBend375\\image11.png', 2],
#  ['data/forwardBend375\\image12.png', 2],
#  ['data/forwardBend375\\image13.png', 2],
#  ['data/forwardBend375\\image14.png', 2],
#  ['data/forwardBend375\\image15.png', 2],
#  ['data/forwardBend375\\image16.png', 2],
#  ['data/forwardBend375\\image17.png', 2],
#  ['data/forwardBend375\\image19.png', 2],
#  ['data/forwardBend375\\image2.png', 2],
#  ['data/forwardBend375\\image20.png', 2],
#  ['data/forwardBend375\\image21.png', 2],
#  ['data/forwardBend375\\image22.png', 2],
#  ['data/forwardBend375\\image23.png', 2],
#  ['data/forwardBend375\\image24.png', 2],
#  ['data/forwardBend375\\image3.png', 2],
#  ['data/forwardBend375\\image4.png', 2],
#  ['data/forwardBend500\\1.jpg', 3],
#  ['data/forwardBend500\\10.jpg', 3],
#  ['data/forwardBend500\\21.jpg', 3],
#  ['data/forwardBend500\\26.jpg', 3],
#  ['data/forwardBend500\\32.jpg', 3],
#  ['data/forwardBend500\\37.jpg', 3],
#  ['data/forwardBend500\\38.jpg', 3],
#  ['data/forwardBend500\\43.jpg', 3],
#  ['data/forwardBend500\\44.jpg', 3],
#  ['data/forwardBend500\\45.jpg', 3],
#  ['data/forwardBend500\\49.jpg', 3],
#  ['data/forwardBend500\\5.jpg', 3],
#  ['data/forwardBend500\\50.jpg', 3],
#  ['data/forwardBend500\\52.jpg', 3],
#  ['data/forwardBend500\\53.jpg', 3],
#  ['data/forwardBend500\\54.jpg', 3],
#  ['data/forwardBend500\\57.jpg', 3],
#  ['data/forwardBend500\\58.jpg', 3],
#  ['data/forwardBend500\\59.jpg', 3],
#  ['data/forwardBend500\\6.jpg', 3],
#  ['data/forwardBend500\\60.jpg', 3],
#  ['data/forwardBend500\\9.jpg', 3],
#  ['data/forwardBend500\\image10.png', 3],
#  ['data/forwardBend500\\image13.png', 3],
#  ['data/forwardBend500\\image14.png', 3],
#  ['data/forwardBend500\\image15.png', 3],
#  ['data/forwardBend500\\image17.png', 3],
#  ['data/forwardBend500\\image4.png', 3],
#  ['data/forwardBend500\\image5.png', 3],
#  ['data/forwardBend500\\image6.png', 3],
#  ['data/forwardBend500\\image7.png', 3],
#  ['data/forwardBend500\\image8.png', 3],
#  ['data/forwardBend500\\image9.png', 3]]

# %%
if __name__ == '__main__':
    with mp_pose.Pose(
            static_image_mode=True,
            model_complexity=2,
            enable_segmentation=True,
            min_detection_confidence=0.5) as pose:
        with open("data\data.txt", "a") as file:
            file.write("angle_1,angle_2,angle_3,angle_4,angle_5,angle_6,angle_7,angle_8,angle_9,angle_10,ground_truth")
            file.write("\n")
        for idx, file in enumerate(IMAGE_FILES):
            image = cv2.imread(file[0])
            image_height, image_width, _ = image.shape
            # Convert the BGR image to RGB before processing.
            results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

            if not results.pose_landmarks:
                continue
            print(
                f'Nose coordinates: ('
                f'{results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].x * image_width}, '
                f'{results.pose_landmarks.landmark[mp_pose.PoseLandmark.NOSE].y * image_height})'
            )
            for idx, landmark in enumerate(results.pose_landmarks.landmark):
                landmark_px = normalized_to_pixel_coordinates(landmark.x, landmark.y, image_width, image_height)
                landmarks = results.pose_landmarks.landmark
            # Get coordinates
            shoulder_right = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                              landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow_right = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist_right = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            shoulder_left = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                             landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            hip_left = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,
                        landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            ankle_left = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,
                          landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            hip_right = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,
                         landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            ankle_right = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            knee_right = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,
                          landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            knee_left = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,
                         landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
            elbow_left = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                          landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist_left = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                          landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            index_left = [landmarks[mp_pose.PoseLandmark.LEFT_INDEX.value].x,
                          landmarks[mp_pose.PoseLandmark.LEFT_INDEX.value].y]
            index_right = [landmarks[mp_pose.PoseLandmark.RIGHT_INDEX.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_INDEX.value].y]

            # Calculate angle
            angle_1 = calculate_angle(shoulder_right, elbow_right, wrist_right)
            angle_2 = calculate_angle(shoulder_left, elbow_left, wrist_left)
            angle_3 = calculate_angle(elbow_right, shoulder_right, hip_right)
            angle_4 = calculate_angle(elbow_left, shoulder_left, hip_left)
            angle_5 = calculate_angle(shoulder_right, hip_right, knee_right)
            angle_6 = calculate_angle(shoulder_left, hip_left, knee_left)
            angle_7 = calculate_angle(hip_right, knee_right, ankle_right)
            angle_8 = calculate_angle(hip_left, knee_left, ankle_left)
            angle_9 = calculate_angle(elbow_left, wrist_left, index_left)
            angle_10 = calculate_angle(elbow_right, wrist_right, index_right)

            lic1 = [angle_1, angle_2, angle_3, angle_4, angle_5, angle_6, angle_7, angle_8, angle_9, angle_10, file[1]]
            print(lic1)
            forwardBend_angle_list.append(lic1)

            with open("data\data.txt", "a") as file:
                for i in range(len(lic1)):
                    if i < len(lic1) - 1:
                        file.write(str(round(lic1[i])) + ",")
                    else:
                        file.write(str(round(lic1[i])))
                file.write("\n")

# %%
image500
# Out:
# [['data/forwardBend500\\1.jpg', 3],
#  ['data/forwardBend500\\10.jpg', 3],
#  ['data/forwardBend500\\21.jpg', 3],
#  ['data/forwardBend500\\26.jpg', 3],
#  ['data/forwardBend500\\32.jpg', 3],
#  ['data/forwardBend500\\37.jpg', 3],
#  ['data/forwardBend500\\38.jpg', 3],
#  ['data/forwardBend500\\43.jpg', 3],
#  ['data/forwardBend500\\44.jpg', 3],
#  ['data/forwardBend500\\45.jpg', 3],
#  ['data/forwardBend500\\49.jpg', 3],
#  ['data/forwardBend500\\5.jpg', 3],
#  ['data/forwardBend500\\50.jpg', 3],
#  ['data/forwardBend500\\52.jpg', 3],
#  ['data/forwardBend500\\53.jpg', 3],
#  ['data/forwardBend500\\54.jpg', 3],
#  ['data/forwardBend500\\57.jpg', 3],
#  ['data/forwardBend500\\58.jpg', 3],
#  ['data/forwardBend500\\59.jpg', 3],
#  ['data/forwardBend500\\6.jpg', 3],
#  ['data/forwardBend500\\60.jpg', 3],
#  ['data/forwardBend500\\9.jpg', 3],
#  ['data/forwardBend500\\image10.png', 3],
#  ['data/forwardBend500\\image13.png', 3],
#  ['data/forwardBend500\\image14.png', 3],
#  ['data/forwardBend500\\image15.png', 3],
#  ['data/forwardBend500\\image17.png', 3],
#  ['data/forwardBend500\\image4.png', 3],
#  ['data/forwardBend500\\image5.png', 3],
#  ['data/forwardBend500\\image6.png', 3],
#  ['data/forwardBend500\\image7.png', 3],
#  ['data/forwardBend500\\image8.png', 3],
#  ['data/forwardBend500\\image9.png', 3]]
